# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivam-Verma1/NLP-lab-Assignments/blob/main/NLP_in_Python_5_Topic_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Topic Modeling

# %% [markdown]
# ## Introduction

# %% [markdown]
# Another popular text analysis technique is called topic modeling. The ultimate goal of topic modeling is to find various topics that are present in your corpus. Each document in the corpus will be made up of at least one topic, if not multiple topics.
#
# In this notebook, we will be covering the steps on how to do **Latent Dirichlet Allocation (LDA)**, which is one of many topic modeling techniques. It was specifically designed for text data.
#
# To use a topic modeling technique, you need to provide (1) a document-term matrix and (2) the number of topics you would like the algorithm to pick up.
#
# Once the topic modeling technique is applied, your job as a human is to interpret the results and see if the mix of words in each topic make sense. If they don't make sense, you can try changing up the number of topics, the terms in the document-term matrix, model parameters, or even try a different model.

# %% [markdown]
# ## Topic Modeling - Attempt #1 (All Text)

# %%
# Let's read in our document-term matrix
import pandas as pd
import pickle

data = pd.read_pickle('dtm.pkl')
data
# Out:
#                                                     abandoned  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...          1
# Napeleon A Corsican Eagle Flown into Legend                 0
# Who Killed Alexander The Great                              0
#
#                                                     abandoned reveals  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...                  1
# Napeleon A Corsican Eagle Flown into Legend                         0
# Who Killed Alexander The Great                                      0
#
#                                                     abdicare  abdicare dopo  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...         0              0
# Napeleon A Corsican Eagle Flown into Legend                2              1
# Who Killed Alexander The Great                             0              0
#
#                                                     abdicare porre  abdicate  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...               0         0
# Napeleon A Corsican Eagle Flown into Legend                      1         2
# Who Killed Alexander The Great                                   0         0
#
#                                                     abdicate attempted  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...                   0
# Napeleon A Corsican Eagle Flown into Legend                          1
# Who Killed Alexander The Great                                       0
#
#                                                     abdicate place  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...               0
# Napeleon A Corsican Eagle Flown into Legend                      1
# Who Killed Alexander The Great                                   0
#
#                                                     abdication  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...           0
# Napeleon A Corsican Eagle Flown into Legend                  1
# Who Killed Alexander The Great                               0
#
#                                                     abdication alienated  ...  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...                     0  ...
# Napeleon A Corsican Eagle Flown into Legend                            1  ...
# Who Killed Alexander The Great                                         0  ...
#
#                                                     zar  zar alessandro  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...    0               0
# Napeleon A Corsican Eagle Flown into Legend           3               3
# Who Killed Alexander The Great                        0               0
#
#                                                     zealand  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...        0
# Napeleon A Corsican Eagle Flown into Legend               0
# Who Killed Alexander The Great                            1
#
#                                                     zealand toxicologist  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...                     0
# Napeleon A Corsican Eagle Flown into Legend                            0
# Who Killed Alexander The Great                                         1
#
#                                                     zone  zone expected  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...     1              1
# Napeleon A Corsican Eagle Flown into Legend            0              0
# Who Killed Alexander The Great                         0              0
#
#                                                     zoppicante  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...           0
# Napeleon A Corsican Eagle Flown into Legend                  1
# Who Killed Alexander The Great                               0
#
#                                                     zoppicante napoleone  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...                     0
# Napeleon A Corsican Eagle Flown into Legend                            1
# Who Killed Alexander The Great                                         0
#
#                                                     zurich  zurich morning
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...       1               1
# Napeleon A Corsican Eagle Flown into Legend              0               0
# Who Killed Alexander The Great                           0               0
#
# [3 rows x 9498 columns]

# %%
# Import the necessary modules for LDA with gensim
# Terminal / Anaconda Navigator: conda install -c conda-forge gensim
from gensim import matutils, models
import scipy.sparse

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# One of the required inputs is a term-document matrix
tdm = data.transpose()
tdm.head()
# Out:
#                    Eye Witness to Iran Hostage Crisis Tehran 4 Nov,1979  \
# abandoned                                                          1
# abandoned reveals                                                  1
# abdicare                                                           0
# abdicare dopo                                                      0
# abdicare porre                                                     0
#
#                    Napeleon A Corsican Eagle Flown into Legend  \
# abandoned                                                    0
# abandoned reveals                                            0
# abdicare                                                     2
# abdicare dopo                                                1
# abdicare porre                                               1
#
#                    Who Killed Alexander The Great
# abandoned                                       0
# abandoned reveals                               0
# abdicare                                        0
# abdicare dopo                                   0
# abdicare porre                                  0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Eye Witness to Iran Hostage Crisis Tehran 4 Nov,1979'].plot(kind='hist', bins=20, title='Eye Witness to Iran Hostage Crisis Tehran 4 Nov,1979')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Napeleon A Corsican Eagle Flown into Legend'].plot(kind='hist', bins=20, title='Napeleon A Corsican Eagle Flown into Legend')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Eye Witness to Iran Hostage Crisis Tehran 4 Nov,1979', y='Napeleon A Corsican Eagle Flown into Legend', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Who Killed Alexander The Great']
#   ys = series['Eye Witness to Iran Hostage Crisis Tehran 4 Nov,1979']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_3.sort_values('Who Killed Alexander The Great', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Who Killed Alexander The Great')
# _ = plt.ylabel('Eye Witness to Iran Hostage Crisis Tehran 4 Nov,1979')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Who Killed Alexander The Great']
#   ys = series['Napeleon A Corsican Eagle Flown into Legend']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('Who Killed Alexander The Great', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Who Killed Alexander The Great')
# _ = plt.ylabel('Napeleon A Corsican Eagle Flown into Legend')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Who Killed Alexander The Great']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Who Killed Alexander The Great'}, axis=1)
#               .sort_values('Who Killed Alexander The Great', ascending=True))
#   xs = counted['Who Killed Alexander The Great']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('Who Killed Alexander The Great', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Who Killed Alexander The Great')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['Eye Witness to Iran Hostage Crisis Tehran 4 Nov,1979'].plot(kind='line', figsize=(8, 4), title='Eye Witness to Iran Hostage Crisis Tehran 4 Nov,1979')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['Napeleon A Corsican Eagle Flown into Legend'].plot(kind='line', figsize=(8, 4), title='Napeleon A Corsican Eagle Flown into Legend')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# We're going to put the term-document matrix into a new gensim format, from df --> sparse matrix --> gensim corpus
sparse_counts = scipy.sparse.csr_matrix(tdm)
corpus = matutils.Sparse2Corpus(sparse_counts)

# %%
# Gensim also requires dictionary of the all terms and their respective location in the term-document matrix
cv = pickle.load(open("cv.pkl", "rb"))
id2word = dict((v, k) for k, v in cv.vocabulary_.items())

# %% [markdown]
# Now that we have the corpus (term-document matrix) and id2word (dictionary of location: term), we need to specify two other parameters - the number of topics and the number of passes. Let's start the number of topics at 2, see if the results make sense, and increase the number from there.

# %%
# Now that we have the corpus (term-document matrix) and id2word (dictionary of location: term),
# we need to specify two other parameters as well - the number of topics and the number of passes
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=2, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.005*"alexander" + 0.004*"alexanders" + 0.003*"death" + 0.003*"lijek" + 0.002*"group" + 0.002*"new" + 0.002*"did" + 0.001*"embassy" + 0.001*"just" + 0.001*"like"'),
#  (1,
#   '0.008*"di" + 0.008*"il" + 0.006*"la" + 0.002*"che" + 0.002*"napoleon" + 0.002*"napoleone" + 0.002*"da" + 0.002*"della" + 0.002*"del" + 0.002*"alla"')]

# %%
# LDA for num_topics = 3
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=3, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.006*"lijek" + 0.003*"group" + 0.003*"embassy" + 0.002*"plan" + 0.002*"compound" + 0.002*"iranian" + 0.002*"tehran" + 0.002*"just" + 0.002*"iran" + 0.002*"protestors"'),
#  (1,
#   '0.007*"di" + 0.006*"il" + 0.005*"alexander" + 0.004*"la" + 0.003*"alexanders" + 0.002*"death" + 0.002*"che" + 0.002*"napoleone" + 0.002*"napoleon" + 0.001*"da"'),
#  (2,
#   '0.000*"alexander" + 0.000*"di" + 0.000*"death" + 0.000*"il" + 0.000*"alexanders" + 0.000*"la" + 0.000*"new" + 0.000*"ancient" + 0.000*"che" + 0.000*"great"')]

# %%
# LDA for num_topics = 4
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=4, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.007*"lijek" + 0.004*"group" + 0.003*"embassy" + 0.002*"plan" + 0.002*"compound" + 0.002*"iranian" + 0.002*"tehran" + 0.002*"just" + 0.002*"iran" + 0.002*"protestors"'),
#  (1,
#   '0.000*"il" + 0.000*"di" + 0.000*"alexander" + 0.000*"alexanders" + 0.000*"la" + 0.000*"death" + 0.000*"che" + 0.000*"lijek" + 0.000*"napoleone" + 0.000*"napoleon"'),
#  (2,
#   '0.009*"alexander" + 0.007*"alexanders" + 0.005*"death" + 0.002*"new" + 0.002*"ancient" + 0.002*"murder" + 0.002*"ptolemy" + 0.002*"stones" + 0.002*"great" + 0.002*"babylon"'),
#  (3,
#   '0.010*"di" + 0.010*"il" + 0.007*"la" + 0.003*"che" + 0.003*"napoleone" + 0.003*"napoleon" + 0.002*"da" + 0.002*"della" + 0.002*"una" + 0.002*"del"')]

# %% [markdown]
# These topics aren't looking too great. We've tried modifying our parameters. Let's try modifying our terms list as well.

# %% [markdown]
# ## Topic Modeling - Attempt #2 (Nouns Only)

# %% [markdown]
# One popular trick is to look only at terms that are from one part of speech (only nouns, only adjectives, etc.). Check out the UPenn tag set: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html.

# %%
# Let's create a function to pull out nouns from a string of text
from nltk import word_tokenize, pos_tag

def nouns(text):
    '''Given a string of text, tokenize the text and pull out only the nouns.'''
    is_noun = lambda pos: pos[:2] == 'NN'
    tokenized = word_tokenize(text)
    all_nouns = [word for (word, pos) in pos_tag(tokenized) if is_noun(pos)]
    return ' '.join(all_nouns)

# %%
# Read in the cleaned data, before the CountVectorizer step
data_clean = pd.read_pickle('data_clean.pkl')
data_clean
# Out:
#                                                                                            transcript
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...  by jonathan ocallaghan in  mark lijek was work...
# Napeleon A Corsican Eagle Flown into Legend         the irresistible rise and rapid fall of the ma...
# Who Killed Alexander The Great                      in his article james romm explores the endurin...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns = pd.DataFrame(data_clean.transcript.apply(nouns))
data_nouns
# Out:
#                                                                                            transcript
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...  jonathan ocallaghan mark lijek tehran officer ...
# Napeleon A Corsican Eagle Flown into Legend         rise fall man europe years mario galloni offic...
# Who Killed Alexander The Great                      article james mystery death alexander bc event...

# %%
data_nouns.transcript
# Out:
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov,1979    jonathan ocallaghan mark lijek tehran officer ...
# Napeleon A Corsican Eagle Flown into Legend             rise fall man europe years mario galloni offic...
# Who Killed Alexander The Great                          article james mystery death alexander bc event...
# Name: transcript, dtype: object

# %%
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

# Convert the set of stop words to a list
add_stop_words = ['like', 'im', 'know', 'just', 'dont', 'thats', 'right', 'people',
                  'youre', 'got', 'gonna', 'time', 'think', 'yeah', 'said']
stop_words = list(text.ENGLISH_STOP_WORDS.union(add_stop_words))

# Recreate a document-term matrix with only nouns
cvn = CountVectorizer(stop_words=stop_words)
data_cvn = cvn.fit_transform(data_nouns.transcript)
data_dtmn = pd.DataFrame(data_cvn.toarray(), columns=cvn.get_feature_names_out())
data_dtmn.index = data_nouns.index
data_dtmn
# Out:
#                                                     abdicare  abdication  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...         0           0
# Napeleon A Corsican Eagle Flown into Legend                2           1
# Who Killed Alexander The Great                             0           0
#
#                                                     ability  absolutism  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...        0           0
# Napeleon A Corsican Eagle Flown into Legend               1           1
# Who Killed Alexander The Great                            0           0
#
#                                                     access  accident  account  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...       0         0        0
# Napeleon A Corsican Eagle Flown into Legend              0         0        0
# Who Killed Alexander The Great                           2         1        2
#
#                                                     accounts  accusers  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...         0         0
# Napeleon A Corsican Eagle Flown into Legend                0         0
# Who Killed Alexander The Great                             5         1
#
#                                                     achievements  ...  yards  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...             0  ...      1
# Napeleon A Corsican Eagle Flown into Legend                    1  ...      0
# Who Killed Alexander The Great                                 0  ...      0
#
#                                                     year  years  york  yorker  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...     2      0     0       0
# Napeleon A Corsican Eagle Flown into Legend            2     10     0       0
# Who Killed Alexander The Great                         0      4     1       2
#
#                                                     youve  zar  zealand  zone  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...      1    0        0     1
# Napeleon A Corsican Eagle Flown into Legend             0    3        0     0
# Who Killed Alexander The Great                          0    0        1     0
#
#                                                     zoppicante
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...           0
# Napeleon A Corsican Eagle Flown into Legend                  1
# Who Killed Alexander The Great                               0
#
# [3 rows x 2027 columns]

# %%
# # Create a new document-term matrix using only nouns
# from sklearn.feature_extraction import text
# from sklearn.feature_extraction.text import CountVectorizer

# # Re-add the additional stop words since we are recreating the document-term matrix
# add_stop_words = ['like', 'im', 'know', 'just', 'dont', 'thats', 'right', 'people',
#                   'youre', 'got', 'gonna', 'time', 'think', 'yeah', 'said']
# stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# # Recreate a document-term matrix with only nouns
# cvn = CountVectorizer(stop_words=stop_words)
# data_cvn = cvn.fit_transform(data_nouns.transcript)
# data_dtmn = pd.DataFrame(data_cvn.toarray(), columns=cvn.get_feature_names())
# data_dtmn.index = data_nouns.index
# data_dtmn

# %%
# Create the gensim corpus
corpusn = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmn.transpose()))

# Create the vocabulary dictionary
id2wordn = dict((v, k) for k, v in cvn.vocabulary_.items())

# %%
# Let's start with 2 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=2, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.018*"alexander" + 0.016*"alexanders" + 0.012*"death" + 0.007*"group" + 0.006*"lijek" + 0.005*"plan" + 0.005*"compound" + 0.004*"stones" + 0.004*"film" + 0.004*"days"'),
#  (1,
#   '0.025*"di" + 0.023*"il" + 0.012*"la" + 0.008*"che" + 0.006*"napoleone" + 0.006*"napoleon" + 0.006*"della" + 0.006*"da" + 0.005*"alla" + 0.004*"nel"')]

# %%
# Let's try topics = 3
ldan = models.LdaModel(corpus=corpusn, num_topics=3, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.020*"di" + 0.019*"il" + 0.013*"alexander" + 0.012*"alexanders" + 0.010*"la" + 0.008*"death" + 0.006*"che" + 0.005*"napoleone" + 0.005*"napoleon" + 0.005*"da"'),
#  (1,
#   '0.015*"group" + 0.012*"lijek" + 0.009*"plan" + 0.009*"compound" + 0.008*"tehran" + 0.007*"protestors" + 0.007*"iran" + 0.006*"americans" + 0.006*"embassy" + 0.006*"wife"'),
#  (2,
#   '0.001*"di" + 0.001*"il" + 0.001*"alexanders" + 0.001*"alexander" + 0.001*"death" + 0.001*"la" + 0.001*"che" + 0.001*"della" + 0.001*"da" + 0.001*"years"')]

# %%
# Let's try 4 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=4, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.017*"group" + 0.013*"lijek" + 0.011*"compound" + 0.010*"plan" + 0.009*"tehran" + 0.008*"protestors" + 0.008*"iran" + 0.007*"americans" + 0.007*"embassy" + 0.006*"building"'),
#  (1,
#   '0.031*"alexander" + 0.028*"alexanders" + 0.020*"death" + 0.006*"murder" + 0.006*"stones" + 0.005*"days" + 0.005*"king" + 0.005*"poison" + 0.005*"babylon" + 0.005*"film"'),
#  (2,
#   '0.030*"di" + 0.028*"il" + 0.015*"la" + 0.009*"che" + 0.007*"napoleone" + 0.007*"della" + 0.007*"da" + 0.007*"napoleon" + 0.006*"alla" + 0.005*"nel"'),
#  (3,
#   '0.001*"di" + 0.001*"il" + 0.001*"la" + 0.001*"che" + 0.001*"alexanders" + 0.001*"alexander" + 0.001*"napoleone" + 0.001*"death" + 0.001*"group" + 0.001*"da"')]

# %% [markdown]
# ## Topic Modeling - Attempt #3 (Nouns and Adjectives)

# %%
# Let's create a function to pull out nouns from a string of text
def nouns_adj(text):
    '''Given a string of text, tokenize the text and pull out only the nouns and adjectives.'''
    is_noun_adj = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ'
    tokenized = word_tokenize(text)
    nouns_adj = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj(pos)]
    return ' '.join(nouns_adj)

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns_adj = pd.DataFrame(data_clean.transcript.apply(nouns_adj))
data_nouns_adj
# Out:
#                                                                                            transcript
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...  jonathan ocallaghan mark lijek tehran consular...
# Napeleon A Corsican Eagle Flown into Legend         irresistible rise rapid fall man europe less y...
# Who Killed Alexander The Great                      article james mystery death alexander great bc...

# %%
# Create a new document-term matrix using only nouns and adjectives, also remove common words with max_df
cvna = CountVectorizer(stop_words=stop_words, max_df=.8)
data_cvna = cvna.fit_transform(data_nouns_adj.transcript)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.get_feature_names_out())
data_dtmna.index = data_nouns_adj.index
data_dtmna
# Out:
#                                                     abdicare  abdication  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...         0           0
# Napeleon A Corsican Eagle Flown into Legend                2           1
# Who Killed Alexander The Great                             0           0
#
#                                                     ability  able  absolutism  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...        0     2           0
# Napeleon A Corsican Eagle Flown into Legend               1     0           1
# Who Killed Alexander The Great                            0     1           0
#
#                                                     absurd  access  accident  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...       0       0         0
# Napeleon A Corsican Eagle Flown into Legend              0       0         0
# Who Killed Alexander The Great                           1       2         2
#
#                                                     accorda  account  ...  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...        0        0  ...
# Napeleon A Corsican Eagle Flown into Legend               1        0  ...
# Who Killed Alexander The Great                            0        2  ...
#
#                                                     year  years  york  yorker  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...     2      0     0       0
# Napeleon A Corsican Eagle Flown into Legend            2     10     0       0
# Who Killed Alexander The Great                         0      4     1       2
#
#                                                     young  youve  zar  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...      0      1    0
# Napeleon A Corsican Eagle Flown into Legend             4      0    3
# Who Killed Alexander The Great                          1      0    0
#
#                                                     zealand  zone  zoppicante
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...        0     1           0
# Napeleon A Corsican Eagle Flown into Legend               0     0           1
# Who Killed Alexander The Great                            1     0           0
#
# [3 rows x 2465 columns]

# %%
# Create the gensim corpus
corpusna = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmna.transpose()))

# Create the vocabulary dictionary
id2wordna = dict((v, k) for k, v in cvna.vocabulary_.items())

# %%
# Let's start with 2 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=2, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.019*"alexander" + 0.017*"alexanders" + 0.013*"death" + 0.005*"ancient" + 0.004*"great" + 0.004*"murder" + 0.004*"stones" + 0.003*"king" + 0.003*"babylon" + 0.003*"antipater"'),
#  (1,
#   '0.019*"il" + 0.018*"di" + 0.009*"la" + 0.006*"che" + 0.005*"napoleone" + 0.004*"napoleon" + 0.004*"group" + 0.004*"da" + 0.004*"della" + 0.004*"alla"')]

# %%
# Let's try 3 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.001*"di" + 0.001*"il" + 0.001*"alexanders" + 0.001*"alexander" + 0.001*"la" + 0.001*"death" + 0.000*"che" + 0.000*"napoleone" + 0.000*"della" + 0.000*"del"'),
#  (1,
#   '0.023*"alexander" + 0.021*"alexanders" + 0.015*"death" + 0.006*"ancient" + 0.005*"great" + 0.005*"stones" + 0.005*"murder" + 0.004*"king" + 0.004*"babylon" + 0.004*"poison"'),
#  (2,
#   '0.020*"il" + 0.020*"di" + 0.010*"la" + 0.006*"che" + 0.005*"napoleone" + 0.005*"napoleon" + 0.005*"group" + 0.004*"da" + 0.004*"della" + 0.004*"una"')]

# %%
# Let's try 4 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.001*"il" + 0.001*"di" + 0.001*"alexander" + 0.001*"alexanders" + 0.001*"la" + 0.001*"death" + 0.000*"lijek" + 0.000*"group" + 0.000*"che" + 0.000*"napoleone"'),
#  (1,
#   '0.027*"il" + 0.026*"di" + 0.013*"la" + 0.008*"che" + 0.006*"napoleone" + 0.006*"napoleon" + 0.006*"della" + 0.006*"da" + 0.006*"alla" + 0.006*"una"'),
#  (2,
#   '0.025*"alexander" + 0.023*"alexanders" + 0.017*"death" + 0.007*"ancient" + 0.006*"great" + 0.005*"murder" + 0.005*"stones" + 0.004*"antipater" + 0.004*"king" + 0.004*"babylon"'),
#  (3,
#   '0.014*"group" + 0.013*"lijek" + 0.009*"plan" + 0.009*"compound" + 0.008*"iranian" + 0.007*"tehran" + 0.007*"protestors" + 0.007*"iran" + 0.007*"embassy" + 0.006*"americans"')]

# %% [markdown]
# ## Identify Topics in Each Document

# %% [markdown]
# Out of the 9 topic models we looked at, the nouns and adjectives, 4 topic one made the most sense. So let's pull that down here and run it through some more iterations to get more fine-tuned topics.

# %%
# Our final LDA model (for now)
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=80)
ldana.print_topics()
# Out:
# [(0,
#   '0.027*"il" + 0.026*"di" + 0.013*"la" + 0.008*"che" + 0.007*"napoleone" + 0.006*"napoleon" + 0.006*"da" + 0.006*"della" + 0.006*"una" + 0.006*"alla"'),
#  (1,
#   '0.014*"group" + 0.013*"lijek" + 0.009*"plan" + 0.009*"compound" + 0.008*"iranian" + 0.007*"tehran" + 0.007*"iran" + 0.007*"embassy" + 0.007*"protestors" + 0.006*"americans"'),
#  (2,
#   '0.025*"alexander" + 0.023*"alexanders" + 0.017*"death" + 0.007*"ancient" + 0.006*"great" + 0.005*"murder" + 0.005*"stones" + 0.004*"king" + 0.004*"babylon" + 0.004*"poison"'),
#  (3,
#   '0.000*"alive" + 0.000*"change" + 0.000*"early" + 0.000*"specific" + 0.000*"remarkable" + 0.000*"reasons" + 0.000*"security" + 0.000*"stress" + 0.000*"vast" + 0.000*"quick"')]

# %% [markdown]
# These four topics look pretty decent. Let's settle on these for now.
# * Topic 0: alexander
# * Topic 1: group,embasssy
# * Topic 2: security
# * Topic 3: napoleone

# %%
# Let's take a look at which topics each transcript contains
corpus_transformed = ldana[corpusna]
list(zip([a for [(a,b)] in corpus_transformed], data_dtmna.index))
# Out:
# [(1, 'Eye Witness to Iran Hostage Crisis Tehran 4 Nov,1979'),
#  (0, 'Napeleon A Corsican Eagle Flown into Legend'),
#  (2, 'Who Killed Alexander The Great')]

# %% [markdown]
# For a first pass of LDA, these kind of make sense to me, so we'll call it a day for now.
# * Topic 0: mom, parents [Anthony, Hasan, Louis, Ricky]
# * Topic 1: husband, wife [Ali, John, Mike]
# * Topic 2: guns [Bill, Bo, Jim]
# * Topic 3: profanity [Dave, Joe]

# %% [markdown]
# ## Additional Exercises

# %% [markdown]
# 1. Try further modifying the parameters of the topic models above and see if you can get better topics.
# 2. Create a new topic model that includes terms from a different [part of speech](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html) and see if you can get better topics.

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=30)
ldana.print_topics()
# Out:
# [(0,
#   '0.000*"di" + 0.000*"il" + 0.000*"alexander" + 0.000*"alexanders" + 0.000*"death" + 0.000*"la" + 0.000*"group" + 0.000*"napoleone" + 0.000*"lijek" + 0.000*"iranian"'),
#  (1,
#   '0.025*"alexander" + 0.023*"alexanders" + 0.017*"death" + 0.007*"ancient" + 0.006*"great" + 0.005*"murder" + 0.005*"stones" + 0.004*"king" + 0.004*"poison" + 0.004*"antipater"'),
#  (2,
#   '0.027*"il" + 0.026*"di" + 0.013*"la" + 0.008*"che" + 0.007*"napoleone" + 0.006*"napoleon" + 0.006*"della" + 0.006*"da" + 0.006*"alla" + 0.006*"una"'),
#  (3,
#   '0.014*"group" + 0.013*"lijek" + 0.009*"plan" + 0.009*"compound" + 0.008*"iranian" + 0.007*"tehran" + 0.007*"iran" + 0.007*"embassy" + 0.007*"protestors" + 0.006*"americans"')]

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=8, id2word=id2wordna, passes=90)
ldana.print_topics()
# Out:
# [(0,
#   '0.000*"di" + 0.000*"il" + 0.000*"la" + 0.000*"alexander" + 0.000*"alexanders" + 0.000*"death" + 0.000*"che" + 0.000*"della" + 0.000*"una" + 0.000*"napoleone"'),
#  (1,
#   '0.030*"alexander" + 0.027*"alexanders" + 0.020*"death" + 0.008*"ancient" + 0.007*"great" + 0.006*"murder" + 0.006*"stones" + 0.005*"king" + 0.005*"poison" + 0.005*"antipater"'),
#  (2,
#   '0.000*"di" + 0.000*"il" + 0.000*"alexanders" + 0.000*"alexander" + 0.000*"la" + 0.000*"death" + 0.000*"group" + 0.000*"napoleon" + 0.000*"della" + 0.000*"che"'),
#  (3,
#   '0.018*"group" + 0.016*"lijek" + 0.011*"plan" + 0.011*"compound" + 0.010*"iranian" + 0.010*"tehran" + 0.009*"iran" + 0.009*"embassy" + 0.009*"protestors" + 0.008*"americans"'),
#  (4,
#   '0.000*"il" + 0.000*"di" + 0.000*"alexander" + 0.000*"alexanders" + 0.000*"death" + 0.000*"la" + 0.000*"napoleone" + 0.000*"che" + 0.000*"plan" + 0.000*"da"'),
#  (5,
#   '0.000*"il" + 0.000*"di" + 0.000*"alexander" + 0.000*"alexanders" + 0.000*"la" + 0.000*"che" + 0.000*"death" + 0.000*"royal" + 0.000*"murder" + 0.000*"course"'),
#  (6,
#   '0.030*"il" + 0.029*"di" + 0.014*"la" + 0.009*"che" + 0.007*"napoleone" + 0.007*"napoleon" + 0.006*"della" + 0.006*"da" + 0.006*"una" + 0.006*"alla"'),
#  (7,
#   '0.000*"group" + 0.000*"alexander" + 0.000*"alexanders" + 0.000*"plan" + 0.000*"death" + 0.000*"il" + 0.000*"lijek" + 0.000*"tehran" + 0.000*"iranian" + 0.000*"compound"')]

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.018*"il" + 0.017*"di" + 0.011*"alexander" + 0.010*"alexanders" + 0.009*"la" + 0.007*"death" + 0.005*"che" + 0.004*"napoleone" + 0.004*"napoleon" + 0.004*"della"'),
#  (1,
#   '0.001*"il" + 0.001*"di" + 0.001*"la" + 0.000*"napoleone" + 0.000*"che" + 0.000*"da" + 0.000*"napoleon" + 0.000*"group" + 0.000*"della" + 0.000*"una"'),
#  (2,
#   '0.012*"group" + 0.011*"lijek" + 0.008*"plan" + 0.008*"compound" + 0.007*"iranian" + 0.007*"tehran" + 0.006*"iran" + 0.006*"embassy" + 0.006*"protestors" + 0.005*"americans"')]

# %% [markdown]
# 2. Create a new topic model that includes terms from a different [part of speech](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html) and see if you can get better topics.
#
#
# What I have changed here is that I included adverb and noun

# %%
# Let's create a function to pull out nouns and adverb from a string of text
def nouns_adj(text):
    '''Given a string of text, tokenize the text and pull out only the nouns and adjectives.'''
    is_noun_adj = lambda pos: pos[:2] == 'NN' or pos[:2] == 'RB'
    tokenized = word_tokenize(text)
    nouns_adj = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj(pos)]
    return ' '.join(nouns_adj)

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns_adj = pd.DataFrame(data_clean.transcript.apply(nouns_adj))
data_nouns_adj

# %%
# Create a new document-term matrix using only nouns and adjectives, also remove common words with max_df
cvna = CountVectorizer(stop_words=stop_words, max_df=.8)
data_cvna = cvna.fit_transform(data_nouns_adj.transcript)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.get_feature_names_out())
data_dtmna.index = data_nouns_adj.index
data_dtmna
# Out:
#                                                     abdicare  abdication  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...         0           0
# Napeleon A Corsican Eagle Flown into Legend                2           1
# Who Killed Alexander The Great                             0           0
#
#                                                     ability  able  absolutism  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...        0     2           0
# Napeleon A Corsican Eagle Flown into Legend               1     0           1
# Who Killed Alexander The Great                            0     1           0
#
#                                                     absurd  access  accident  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...       0       0         0
# Napeleon A Corsican Eagle Flown into Legend              0       0         0
# Who Killed Alexander The Great                           1       2         2
#
#                                                     accorda  account  ...  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...        0        0  ...
# Napeleon A Corsican Eagle Flown into Legend               1        0  ...
# Who Killed Alexander The Great                            0        2  ...
#
#                                                     year  years  york  yorker  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...     2      0     0       0
# Napeleon A Corsican Eagle Flown into Legend            2     10     0       0
# Who Killed Alexander The Great                         0      4     1       2
#
#                                                     young  youve  zar  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...      0      1    0
# Napeleon A Corsican Eagle Flown into Legend             4      0    3
# Who Killed Alexander The Great                          1      0    0
#
#                                                     zealand  zone  zoppicante
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...        0     1           0
# Napeleon A Corsican Eagle Flown into Legend               0     0           1
# Who Killed Alexander The Great                            1     0           0
#
# [3 rows x 2465 columns]

# %%
# Create the gensim corpus
corpusna = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmna.transpose()))

id2wordna = dict((v, k) for k, v in cvna.vocabulary_.items())

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=500)
ldana.print_topics()

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=10000)
ldana.print_topics()
