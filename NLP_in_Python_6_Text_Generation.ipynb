# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivam-Verma1/NLP-lab-Assignments/blob/main/NLP_in_Python_6_Text_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                                                            transcript  \
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...  by Jonathan O’Callaghan In 1979, Mark Lijek wa...
# Napeleon A Corsican Eagle Flown into Legend         The irresistible rise and rapid fall of the ma...
# Who Killed Alexander The Great                      In his article, James Romm explores the enduri...
#
#                                                                   Author
# Eye Witness to Iran Hostage Crisis Tehran 4 Nov...  Jonathan O’Callaghan
# Napeleon A Corsican Eagle Flown into Legend                      Anthony
# Who Killed Alexander The Great                             Richard Wills

# %%
# Extract only Ali Wong's text
ali_text = data.transcript.loc['Who Killed Alexander The Great']
ali_text[:200]
# Out:
# 'In his article, James Romm explores the enduring mystery surrounding the death of Alexander the Great in 323 BC, an event that has baffled historians and sparked numerous theories over the centuries. '

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''

    # Tokenize the text by word, though including punctuation
    words = text.split(' ')

    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)

    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ali_dict = markov_chain(ali_text)
ali_dict
# Out:
# {'In': ['his',
#   'Babylon',
#   '325,',
#   '1996',
#   'its',
#   'India',
#   'this',
#   'the',
#   'Babylon,',
#   '1913',
#   'his',
#   'Atkinson’s'],
#  'his': ['article,',
#   'robust',
#   'empire',
#   'death.',
#   'own',
#   'demise',
#   '12-year',
#   'lungs',
#   'military',
#   '50,000-strong',
#   'death).',
#   'Companions,',
#   'commander’s',
#   'words',
#   'murder',
#   'death.',
#   'scribe',
#   'troops',
#   'sickbed,',
#   'eyes',
#   'biography',
#   'sons,',
#   'post',
#   'stead.',
#   'son',
#   'brother',
#   'former',
#   'relative',
#   'ashes',
#   'high',
#   'sons',
#   'sons',
#   '2004',
#   'two',
#   'view,',
#   'corpse',
#   'descendant',
#   'final',
#   'closest',
#   'co-authors',
#   'own',
#   'men',
#   'own',
#   'symptoms.',
#   'inner',
#   'mind',
#   'will',
#   'death,',
#   'final',
#   'death',
#   'enemies',
#   'Berkeley'],
#  'article,': ['James'],
#  'James': ['Romm', 'Romm', 'H.', 'Romm'],
# ...

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ali_dict)
# Out:
# 'Reviews Oliver Stone’s film appears to survive’, Atkinson rejects the era after his lungs pierced.'

# %% [markdown]
# ## Additional Exercises

# %% [markdown]
# 1. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
import random
import string

def generate_sentence2(chain, max_words=30):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the maximum number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = [word1.capitalize()]

    # Generate the subsequent words
    for _ in range(max_words - 1):
        word2 = random.choice(chain.get(word1, ['.']))  # Default to '.' if word1 not found in chain
        if word2.endswith(tuple(string.punctuation)):
            sentence.append(word2)
            break
        word1 = word2
        sentence.append(word2)

    # Convert the list of words into a sentence
    sentence = ' '.join(sentence)

    # Ensure the sentence ends with a random punctuation mark
    if not sentence.endswith(tuple(string.punctuation)):
        sentence += random.choice(string.punctuation)

    return sentence

# %%
generate_sentence2(ali_dict)
# Out:
# 'Ideal weapon for causes.'
